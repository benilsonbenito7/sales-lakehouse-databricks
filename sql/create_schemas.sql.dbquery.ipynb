-- %%
CREATE SCHEMA IF NOT EXISTS retail_sales.bronze
COMMENT 'CAMADA BRONZE PARA DADOS BRUTOS DAS VENDAS';

CREATE SCHEMA IF NOT EXISTS retail_sales.silver
COMMENT 'CAMADA SILVER PARA DADOS TRATADOS DAS VENDAS';

CREATE SCHEMA IF NOT EXISTS retail_sales.gold
COMMENT 'CAMADA GOLD PARA DADOS ANALITICOS DAS VENDAS';
